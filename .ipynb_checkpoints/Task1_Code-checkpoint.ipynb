# %%
# We import finspark to make pyspark importable as a regular library.
import findspark
findspark.init() 

import pyspark # Import pyspark
from pyspark.sql import SparkSession # Import spark session class
from pyspark.sql.functions import isnan, when, count, col # Import some general useful pyspark functions
import pandas as pd # Import pandas for any data manipulation and visualisations
import matplotlib.pyplot as plt # Import matplotlib for data viz
import seaborn as sns # Import seaborn also for data viz

# Create instance of the class
spark = SparkSession.builder.getOrCreate()

# Creates wider cells so we can view more info when displaying data
from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
# We need to tell spark that the schema should be “inferred” from the data,
# but also, we want to tell it to use the headers from the columns
df = spark.read.csv("Task_1_dataset/nuclear_plants_small_dataset.csv", inferSchema=True,header=True)

# %%
# Look at the basic structure of the data
df.printSchema()
# Out:
# root
#  |-- Status: string (nullable = true)
#  |-- Power_range_sensor_1: double (nullable = true)
#  |-- Power_range_sensor_2: double (nullable = true)
#  |-- Power_range_sensor_3 : double (nullable = true)
#  |-- Power_range_sensor_4: double (nullable = true)
#  |-- Pressure _sensor_1: double (nullable = true)
#  |-- Pressure _sensor_2: double (nullable = true)
#  |-- Pressure _sensor_3: double (nullable = true)
#  |-- Pressure _sensor_4: double (nullable = true)
#  |-- Vibration_sensor_1: double (nullable = true)
#  |-- Vibration_sensor_2: double (nullable = true)
#  |-- Vibration_sensor_3: double (nullable = true)
#  |-- Vibration_sensor_4: double (nullable = true)

# %%
# We can see in the column names there are random spaces that could cause key errors in later analysis
from pyspark.sql.functions import col # Import col function to select a specfic column from dataframe

# Replace space in all columns of the dataframe with nothing
df = df.select([col(column).alias(column.replace(' ', '')) for column in df.columns])

# %%
# Find num of null values for each column
df.select([count(when(col(c).isNull(),c)).alias(c) for c in df.columns]).show(vertical=True)
# Out:
# -RECORD 0-------------------
#  Status               | 0
#  Power_range_sensor_1 | 0
#  Power_range_sensor_2 | 0
#  Power_range_sensor_3 | 0
#  Power_range_sensor_4 | 0
#  Pressure_sensor_1    | 0
#  Pressure_sensor_2    | 0
#  Pressure_sensor_3    | 0
#  Pressure_sensor_4    | 0
#  Vibration_sensor_1   | 0
#  Vibration_sensor_2   | 0
#  Vibration_sensor_3   | 0
#  Vibration_sensor_4   | 0

# %%
# For each group (in status column), show: minimum, maximum, mean, and median values, for each feature in the dataframe.

# Converts current pyspark dataframe to pandas to be able to calculate agg functions in cleaner format
df_pandas = df.toPandas() 

df_pandas.groupby(['Status']).median()
# Out:
#           Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3  \
# Status
# Abnormal               4.51355              5.932218               9.47205
# Normal                 5.17865              6.717650               9.26285
#
#           Power_range_sensor_4  Pressure_sensor_1  Pressure_sensor_2  \
# Status
# Abnormal               5.39930           12.59615           2.382689
# Normal                 9.24085           10.63480           3.113000
#
#           Pressure_sensor_3  Pressure_sensor_4  Vibration_sensor_1  \
# Status
# Abnormal           5.744257           3.322575             6.53595
# Normal             5.739400           4.259150             7.44990
#
#           Vibration_sensor_2  Vibration_sensor_3  Vibration_sensor_4
# Status
# Abnormal             8.97310            8.987269             8.13760
# Normal               8.70075           16.464500             9.48545

# %%
# Calcuate the mean for each group in "Status" column
df_pandas.groupby(['Status']).mean()
# Out:
#           Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3  \
# Status
# Abnormal              4.396695              5.914043              9.164170
# Normal                5.602453              6.844503              9.292054
#
#           Power_range_sensor_4  Pressure_sensor_1  Pressure_sensor_2  \
# Status
# Abnormal              6.009146          14.600728           2.740270
# Normal                8.701398          13.797526           3.415646
#
#           Pressure_sensor_3  Pressure_sensor_4  Vibration_sensor_1  \
# Status
# Abnormal           5.575115           4.407824            7.887689
# Normal             5.923353           5.586180            8.441437
#
#           Vibration_sensor_2  Vibration_sensor_3  Vibration_sensor_4
# Status
# Abnormal           10.303570           10.938159            8.942085
# Normal              9.699616           19.437804           10.925098

# %%
# Calcuate the max for each group in "Status" column
df_pandas.groupby(['Status']).max()
# Out:
#           Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3  \
# Status
# Abnormal             10.923078               10.1541               15.7599
# Normal               12.129800               11.9284               14.0982
#
#           Power_range_sensor_4  Pressure_sensor_1  Pressure_sensor_2  \
# Status
# Abnormal             17.235858            67.9794          10.242738
# Normal               16.356800            56.8562           9.221200
#
#           Pressure_sensor_3  Pressure_sensor_4  Vibration_sensor_1  \
# Status
# Abnormal            11.7724           16.55562           36.186438
# Normal              12.6475           15.10850           31.498100
#
#           Vibration_sensor_2  Vibration_sensor_3  Vibration_sensor_4
# Status
# Abnormal           34.331466           36.911454             26.4669
# Normal             34.867600           53.238400             43.2314

# %%
# Calcuate the min for each group in "Status" column
df_pandas.groupby(['Status']).min()
# Out:
#           Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3  \
# Status
# Abnormal                0.0082                0.3891              2.583966
# Normal                  0.0851                0.0403              4.382600
#
#           Power_range_sensor_4  Pressure_sensor_1  Pressure_sensor_2  \
# Status
# Abnormal                0.0623           0.131478           0.008262
# Normal                  0.1547           0.024800           0.010400
#
#           Pressure_sensor_3  Pressure_sensor_4  Vibration_sensor_1  \
# Status
# Abnormal           0.001224           0.029478              0.0000
# Normal             0.077400           0.005800              0.0092
#
#           Vibration_sensor_2  Vibration_sensor_3  Vibration_sensor_4
# Status
# Abnormal              0.0185            0.131784              0.0092
# Normal                0.0277            0.064600              0.0831

# %%
# Create box plot for each group in "Status" column

# Get seperate dataframe for each group in "Status" column, then convert to pandas so we can use to make visualisations
df_abnormal = df.filter(df.Status == "Abnormal").toPandas()
df_normal = df.filter(df.Status == "Normal").toPandas()

df_abnormal.head()
# Out:
#      Status  Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3  \
# 0  Abnormal                8.4467                5.8667                9.1736
# 1  Abnormal                7.7426                5.7504                9.4666
# 2  Abnormal                7.7426                5.6149               10.2393
# 3  Abnormal                7.3059                5.7349               10.2228
# 4  Abnormal                5.8740                5.9592                9.1791
#
#    Power_range_sensor_4  Pressure_sensor_1  Pressure_sensor_2  \
# 0               11.6904             1.1803             1.4415
# 1               11.3361             2.0382             1.2612
# 2               11.2692             5.2864             1.5143
# 3               11.4734             9.4818             1.8207
# 4               11.1758            10.2951             1.4392
#
#    Pressure_sensor_3  Pressure_sensor_4  Vibration_sensor_1  \
# ...

# %%
# Create box plots for all features for both groups (Status)

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting abnormal "Power Range Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Abnormal Status Power Range Sensor Boxplots', fontsize=13)

# Add graphs off each power range sensor feature for abnormal data to subplots
df_abnormal.boxplot(column = "Power_range_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Power_range_sensor_1 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Power_range_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Power_range_sensor_2 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Power_range_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Power_range_sensor_3 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Power_range_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Power_range_sensor_4 Distribution', fontsize = 10)  
figure.tight_layout()

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting abnormal "Pressure Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Abnormal Status Pressure Sensor Boxplots', fontsize=13)

# Add graphs off each pressure sensor feature for abnormal data to subplots
df_abnormal.boxplot(column = "Pressure_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Pressure_sensor_1 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Pressure_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Pressure_sensor_2 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Pressure_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Pressure_sensor_3 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Pressure_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Pressure_sensor_4 Distribution', fontsize = 10)
figure.tight_layout()

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting abnormal "Vibration Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Abnormal Status Vibration Sensor Boxplots', fontsize=13)

# Add graphs off each vibration sensor feature for abnormal data to subplots
df_abnormal.boxplot(column = "Vibration_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Vibration_sensor_1 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Vibration_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Vibration_sensor_2 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Vibration_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Vibration_sensor_3 Distribution', fontsize = 10)

df_abnormal.boxplot(column = "Vibration_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Vibration_sensor_4 Distribution', fontsize = 10)
figure.tight_layout()

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting normal "Power Range Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Normal Status Power Range Sensor Boxplots', fontsize=13)

# Add graphs off each power range sensor feature for normal data to subplots
df_normal.boxplot(column = "Power_range_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Power_range_sensor_1 Distribution', fontsize = 10)

df_normal.boxplot(column = "Power_range_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Power_range_sensor_2 Distribution', fontsize = 10)

df_normal.boxplot(column = "Power_range_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Power_range_sensor_3 Distribution', fontsize = 10)

df_normal.boxplot(column = "Power_range_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Power_range_sensor_4 Distribution', fontsize = 10)  
figure.tight_layout()

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting normal "Pressure Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Normal Status Pressure Sensor Boxplots', fontsize=13)

# Add graphs off each pressure sensor feature for normal data to subplots
df_normal.boxplot(column = "Pressure_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Pressure_sensor_1 Distribution', fontsize = 10)

df_normal.boxplot(column = "Pressure_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Pressure_sensor_2 Distribution', fontsize = 10)

df_normal.boxplot(column = "Pressure_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Pressure_sensor_3 Distribution', fontsize = 10)

df_normal.boxplot(column = "Pressure_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Pressure_sensor_4 Distribution', fontsize = 10)
figure.tight_layout()

# %%
# Initialise the subplot function using number of rows and columns (4x4) for plotting normal "Vibration Sensors"
figure, axes = plt.subplots(2, 2)
figure.suptitle('Normal Status Vibration Sensor Boxplots', fontsize=13)

# Add graphs off each vibration sensor feature for normal data to subplots
df_normal.boxplot(column = "Vibration_sensor_1", fontsize= '8', grid = True, ax=axes[0,0])
axes[0,0].set_title('Vibration_sensor_1 Distribution', fontsize = 10)

df_normal.boxplot(column = "Vibration_sensor_2", fontsize= '8', grid = True, ax=axes[0,1])
axes[0,1].set_title('Vibration_sensor_2 Distribution', fontsize = 10)

df_normal.boxplot(column = "Vibration_sensor_3", fontsize= '8', grid = True, ax=axes[1,0])
axes[1,0].set_title('Vibration_sensor_3 Distribution', fontsize = 10)

df_normal.boxplot(column = "Vibration_sensor_4", fontsize= '8', grid = True, ax=axes[1,1])
axes[1,1].set_title('Vibration_sensor_4 Distribution', fontsize = 10)
figure.tight_layout()

# %%
# Understand the relationship between features.

# Set the figure size
fig, ax = plt.subplots(figsize=(10,9))

# Create a correlation matrix of all the features in the main dataset (not split by status)
# We know that the "Status" column wont have much relevance in correlation matrix, so we can drop it
sns.heatmap(df_pandas.drop("Status", axis=1).corr(), annot=True, cmap="coolwarm")

plt.show()
